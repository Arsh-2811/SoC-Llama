# %% [markdown]
# # Necessary Libraries

# %%
from dataclasses import dataclass
from typing import Any, Optional, Tuple

import torch
import torch.nn.functional as F
from torch import nn

import pandas as pd
import random
import math
import os

from torch.utils.tensorboard import SummaryWriter

from torch.optim import Optimizer
from torch.optim.lr_scheduler import _LRScheduler

import matplotlib.pyplot as plt
# Out:
# C:\Users\arshs\AppData\Local\Temp\ipykernel_9440\4204762261.py:8: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
writer = SummaryWriter("runs/socllama")
# tensorboard --logdir runs

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# # Required Parameters

# %%
req_parameters = [
                  'Velocity [km/h]', 'Throttle [%]', 'Motor Torque [Nm]', 'Regenerative Braking Signal ', 'Battery Voltage [V]', 
                  'Battery Current [A]','SoC [%]'
                 ]

# %% [markdown]
# # Model Implementation

# %%
dataclass
class ModelArgs:
    dim: int = 256
    n_layers: int = 2
    n_heads: int = 8
    n_kv_heads: Optional[int] = None
    #vocab_size: int = 32000
    n_features : int = len(req_parameters)
    hidden_dim: Optional[int] = None
    multiple_of: int = 256  # MLP hidden layer size will be multiple of
    norm_eps: float = 1e-5
    max_seq_len: int = 300
    dropout: float = 0.2

    max_batch_size : int = 5
    lr : float = 0.01
    epochs : int = 4000
    split_ratio : float = 0.8

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

class RMSNorm(torch.nn.Module):
    def __init__(self, dim: int, eps: float):
        super().__init__()
        self.eps = eps
        self.weight = nn.Parameter(torch.ones(dim)).to(device)

    def _norm(self, x):
        return x * torch.rsqrt(x.pow(2).mean(-1, keepdim=True) + self.eps)

    def forward(self, x):
        output = self._norm(x.float()).type_as(x)
        return output * self.weight


def precompute_freqs_cis(dim: int, end: int, theta: float = 10000.0):
    freqs = 1.0 / (theta ** (torch.arange(0, dim, 2)[: (dim // 2)].float() / dim)).to(device)
    t = torch.arange(end, device=freqs.device).to(device)  # type: ignore
    freqs = torch.outer(t, freqs).float().to(device)  # type: ignore
    freqs_cos = torch.cos(freqs).to(device)  # real part
    freqs_sin = torch.sin(freqs).to(device)  # imaginary part
    return freqs_cos, freqs_sin

def reshape_for_broadcast(freqs_cis: torch.Tensor, x: torch.Tensor):
    ndim = x.ndim
    assert 0 <= 1 < ndim
    assert freqs_cis.shape == (x.shape[1], x.shape[-1])
    shape = [d if i == 1 or i == ndim - 1 else 1 for i, d in enumerate(x.shape)]
    return freqs_cis.view(shape)

def apply_rotary_emb(xq: torch.Tensor, xk: torch.Tensor, freqs_cos: torch.Tensor, freqs_sin: torch.Tensor) -> Tuple[torch.Tensor, torch.Tensor]:
    # reshape xq and xk to match the complex representation
    xq_r, xq_i = xq.float().reshape(xq.shape[:-1] + (-1, 2)).unbind(-1)
    xk_r, xk_i = xk.float().reshape(xk.shape[:-1] + (-1, 2)).unbind(-1)

    # reshape freqs_cos and freqs_sin for broadcasting
    freqs_cos = reshape_for_broadcast(freqs_cos, xq_r)
    freqs_sin = reshape_for_broadcast(freqs_sin, xq_r)

    # apply rotation using real numbers
    xq_out_r = xq_r * freqs_cos - xq_i * freqs_sin
    xq_out_i = xq_r * freqs_sin + xq_i * freqs_cos
    xk_out_r = xk_r * freqs_cos - xk_i * freqs_sin
    xk_out_i = xk_r * freqs_sin + xk_i * freqs_cos

    # flatten last two dimensions
    xq_out = torch.stack([xq_out_r, xq_out_i], dim=-1).flatten(3)
    xk_out = torch.stack([xk_out_r, xk_out_i], dim=-1).flatten(3)

    return xq_out.type_as(xq), xk_out.type_as(xk)

def repeat_kv(x: torch.Tensor, n_rep: int) -> torch.Tensor:
    """torch.repeat_interleave(x, dim=2, repeats=n_rep)"""
    bs, slen, n_kv_heads, head_dim = x.shape
    if n_rep == 1:
        return x
    return (
        x[:, :, :, None, :]
        .expand(bs, slen, n_kv_heads, n_rep, head_dim)
        .reshape(bs, slen, n_kv_heads * n_rep, head_dim)
    )

class Attention(nn.Module):
    def __init__(self, args: ModelArgs):
        super().__init__()
        self.n_kv_heads = args.n_heads if args.n_kv_heads is None else args.n_kv_heads
        assert args.n_heads % self.n_kv_heads == 0
        model_parallel_size = 1
        self.n_local_heads = args.n_heads // model_parallel_size
        self.n_local_kv_heads = self.n_kv_heads // model_parallel_size
        self.n_rep = self.n_local_heads // self.n_local_kv_heads
        self.head_dim = args.dim // args.n_heads
        self.wq = nn.Linear(args.dim, args.n_heads * self.head_dim, bias=False)
        self.wk = nn.Linear(args.dim, self.n_kv_heads * self.head_dim, bias=False)
        self.wv = nn.Linear(args.dim, self.n_kv_heads * self.head_dim, bias=False)
        self.wo = nn.Linear(args.n_heads * self.head_dim, args.dim, bias=False)
        self.attn_dropout = nn.Dropout(args.dropout)
        self.resid_dropout = nn.Dropout(args.dropout)
        self.dropout = args.dropout

        # use flash attention or a manual implementation?
        self.flash = hasattr(torch.nn.functional, 'scaled_dot_product_attention')
        if not self.flash:
            print("WARNING: using slow attention. Flash Attention requires PyTorch >= 2.0")
            mask = torch.full((1, 1, args.max_seq_len, args.max_seq_len), float("-inf"))
            mask = torch.triu(mask, diagonal=1)
            self.register_buffer("mask", mask)

    def forward(self, x: torch.Tensor, freqs_cos: torch.Tensor, freqs_sin: torch.Tensor,):
        bsz, seqlen, _ = x.shape

        # QKV
        xq, xk, xv = self.wq(x), self.wk(x), self.wv(x)
        xq = xq.view(bsz, seqlen, self.n_local_heads, self.head_dim)
        xk = xk.view(bsz, seqlen, self.n_local_kv_heads, self.head_dim)
        xv = xv.view(bsz, seqlen, self.n_local_kv_heads, self.head_dim)

        # RoPE relative positional embeddings
        xq, xk = apply_rotary_emb(xq, xk, freqs_cos, freqs_sin)

        # grouped multiquery attention: expand out keys and values
        xk = repeat_kv(xk, self.n_rep)  # (bs, seqlen, n_local_heads, head_dim)
        xv = repeat_kv(xv, self.n_rep)  # (bs, seqlen, n_local_heads, head_dim)

        # make heads into a batch dimension
        xq = xq.transpose(1, 2)  # (bs, n_local_heads, seqlen, head_dim)
        xk = xk.transpose(1, 2)
        xv = xv.transpose(1, 2)

        # flash implementation
        if self.flash:
            output = torch.nn.functional.scaled_dot_product_attention(xq, xk, xv, attn_mask=None, dropout_p=self.dropout if self.training else 0.0, is_causal=True)
        else:
            # manual implementation
            scores = torch.matmul(xq, xk.transpose(2, 3)) / math.sqrt(self.head_dim)
            assert hasattr(self, 'mask')
            scores = scores + self.mask[:, :, :seqlen, :seqlen]   # (bs, n_local_heads, seqlen, cache_len + seqlen)
            scores = F.softmax(scores.float(), dim=-1).type_as(xq)
            scores = self.attn_dropout(scores)
            output = torch.matmul(scores, xv)  # (bs, n_local_heads, seqlen, head_dim)

        # restore time as batch dimension and concat heads
        output = output.transpose(1, 2).contiguous().view(bsz, seqlen, -1)

        # final projection into the residual stream
        output = self.wo(output)
        output = self.resid_dropout(output)
        return output

class FeedForward(nn.Module):
    def __init__(self, dim: int, hidden_dim: int, multiple_of: int, dropout: float):
        super().__init__()
        if hidden_dim is None:
            hidden_dim = 4 * dim
            hidden_dim = int(2 * hidden_dim / 3)
            hidden_dim = multiple_of * ((hidden_dim + multiple_of - 1) // multiple_of)
        self.w1 = nn.Linear(dim, hidden_dim, bias=False)
        self.w2 = nn.Linear(hidden_dim, dim, bias=False)
        self.w3 = nn.Linear(dim, hidden_dim, bias=False)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        return self.dropout(self.w2(F.silu(self.w1(x)) * self.w3(x)))


class TransformerBlock(nn.Module):
    def __init__(self, layer_id: int, args: ModelArgs):
        super().__init__()
        self.n_heads = args.n_heads
        self.dim = args.dim
        self.head_dim = args.dim // args.n_heads
        self.attention = Attention(args)
        self.feed_forward = FeedForward(
            dim=args.dim,
            hidden_dim=args.hidden_dim,
            multiple_of=args.multiple_of,
            dropout=args.dropout,
        )
        self.layer_id = layer_id
        self.attention_norm = RMSNorm(args.dim, eps=args.norm_eps)
        self.ffn_norm = RMSNorm(args.dim, eps=args.norm_eps)

    def forward(self, x, freqs_cos, freqs_sin):
        h = x + self.attention.forward(self.attention_norm(x), freqs_cos, freqs_sin)
        out = h + self.feed_forward.forward(self.ffn_norm(h))
        return out


class Transformer(nn.Module):
    last_loss: Optional[torch.Tensor]

    def __init__(self, params: ModelArgs):
        super().__init__()
        self.params = params
        # self.vocab_size = params.vocab_size
        self.n_layers = params.n_layers

        # self.tok_embeddings = nn.Embedding(params.vocab_size, params.dim)
        self.tok_embeddings = nn.Linear(params.n_features, params.dim, bias=False)

        self.dropout = nn.Dropout(params.dropout)
        self.layers = torch.nn.ModuleList()
        for layer_id in range(params.n_layers):
            self.layers.append(TransformerBlock(layer_id, params))
        self.norm = RMSNorm(params.dim, eps=params.norm_eps)

        #self.output = nn.Linear(params.dim, params.vocab_size, bias=False)
        self.output = nn.Linear(params.dim, 1, bias = False)

        # share the unembedding parameters with the embedding parameters
        #self.tok_embeddings.weight = self.output.weight # https://paperswithcode.com/method/weight-tying

        # some useful precompute for the RoPE relative positional embeddings
        freqs_cos, freqs_sin = precompute_freqs_cis(self.params.dim // self.params.n_heads, self.params.max_seq_len)
        self.register_buffer("freqs_cos", freqs_cos, persistent=False)
        self.register_buffer("freqs_sin", freqs_sin, persistent=False)

        # init all weights
        self.apply(self._init_weights)
        # apply special scaled init to the residual projections, per GPT-2 paper
        for pn, p in self.named_parameters():
            if pn.endswith('w3.weight') or pn.endswith('wo.weight'):
                torch.nn.init.normal_(p, mean=0.0, std=0.02/math.sqrt(2 * params.n_layers))

        # Initialize attribute for the loss of the last forward call. This will be set if the forward is called with a targets tensor.
        self.last_loss = None

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, tokens: torch.Tensor, targets: Optional[torch.Tensor] = None) -> torch.Tensor:
        _bsz, seqlen, n_features = tokens.shape
        h = self.tok_embeddings(tokens)
        h = self.dropout(h)
        freqs_cos = self.freqs_cos[:seqlen]
        freqs_sin = self.freqs_sin[:seqlen]

        for layer in self.layers:
            h = layer(h, freqs_cos, freqs_sin)
        h = self.norm(h)
        h = h[:, -1, :]
        logits = self.output(h)

        # if targets is not None:
        #     # if we are given some desired targets also calculate the loss
        #     logits = self.output(h)
        #     self.last_loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1), ignore_index=-1)
        # else:
        #     # inference-time mini-optimization: only forward the output on the very last position
        #     logits = self.output(h[:, [-1], :]) # note: using list [-1] to preserve the time dim
        #     self.last_loss = None

        return torch.squeeze(logits)

    # def configure_optimizers(self, weight_decay, learning_rate, betas, device_type):
    #     # start with all of the candidate parameters
    #     param_dict = {pn: p for pn, p in self.named_parameters()}
    #     # filter out those that do not require grad
    #     param_dict = {pn: p for pn, p in param_dict.items() if p.requires_grad}
    #     # create optim groups. Any parameters that is 2D will be weight decayed, otherwise no.
    #     # i.e. all weight tensors in matmuls + embeddings decay, all biases and layernorms don't.
    #     decay_params = [p for n, p in param_dict.items() if p.dim() >= 2]
    #     nodecay_params = [p for n, p in param_dict.items() if p.dim() < 2]
    #     optim_groups = [
    #         {'params': decay_params, 'weight_decay': weight_decay},
    #         {'params': nodecay_params, 'weight_decay': 0.0}
    #     ]
    #     num_decay_params = sum(p.numel() for p in decay_params)
    #     num_nodecay_params = sum(p.numel() for p in nodecay_params)
    #     print(f"num decayed parameter tensors: {len(decay_params)}, with {num_decay_params:,} parameters")
    #     print(f"num non-decayed parameter tensors: {len(nodecay_params)}, with {num_nodecay_params:,} parameters")
    #     # Create AdamW optimizer and use the fused version if it is available
    #     fused_available = 'fused' in inspect.signature(torch.optim.AdamW).parameters
    #     use_fused = fused_available and device_type == 'cuda'
    #     extra_args = dict(fused=True) if use_fused else dict()
    #     optimizer = torch.optim.AdamW(optim_groups, lr=learning_rate, betas=betas, **extra_args)
    #     print(f"using fused AdamW: {use_fused}")

    #     return optimizer

    # def estimate_mfu(self, fwdbwd_per_iter, dt):
    #     """ estimate model flops utilization (MFU) in units of A100 bfloat16 peak FLOPS """
    #     # first estimate the number of flops we do per iteration.
    #     # see PaLM paper Appendix B as ref: https://arxiv.org/abs/2204.02311
    #     N = sum(p.numel() for p in self.parameters())
    #     cfg = self.params
    #     L, H, Q, T = cfg.n_layers, cfg.n_heads, cfg.dim//cfg.n_heads, cfg.max_seq_len
    #     flops_per_token = 6*N + 12*L*H*Q*T
    #     flops_per_fwdbwd = flops_per_token * T
    #     flops_per_iter = flops_per_fwdbwd * fwdbwd_per_iter
    #     # express our flops throughput as ratio of A100 bfloat16 peak flops
    #     flops_achieved = flops_per_iter * (1.0/dt) # per second
    #     flops_promised = 312e12 # A100 GPU bfloat16 peak flops is 312 TFLOPS
    #     mfu = flops_achieved / flops_promised
    #     return mfu

    # @torch.inference_mode()
    # def generate(self, idx, max_new_tokens, temperature=1.0, top_k=None):
    #     """
    #     Take a conditioning sequence of indices idx (LongTensor of shape (b,t)) and complete
    #     the sequence max_new_tokens times, feeding the predictions back into the model each time.
    #     Most likely you'll want to make sure to be in model.eval() mode of operation for this.
    #     Also note this is a super inefficient version of sampling with no key/value cache.
    #     """
    #     for _ in range(max_new_tokens):
    #         # if the sequence context is growing too long we must crop it at block_size
    #         idx_cond = idx if idx.size(1) <= self.params.max_seq_len else idx[:, -self.params.max_seq_len:]
    #         # forward the model to get the logits for the index in the sequence
    #         logits = self(idx_cond)
    #         logits = logits[:, -1, :] # crop to just the final time step
    #         if temperature == 0.0:
    #             # "sample" the single most likely index
    #             _, idx_next = torch.topk(logits, k=1, dim=-1)
    #         else:
    #             # pluck the logits at the final step and scale by desired temperature
    #             logits = logits / temperature
    #             # optionally crop the logits to only the top k options
    #             if top_k is not None:
    #                 v, _ = torch.topk(logits, min(top_k, logits.size(-1)))
    #                 logits[logits < v[:, [-1]]] = -float('Inf')
    #             # apply softmax to convert logits to (normalized) probabilities
    #             probs = F.softmax(logits, dim=-1)
    #             idx_next = torch.multinomial(probs, num_samples=1)
    #         # append sampled index to the running sequence and continue
    #         idx = torch.cat((idx, idx_next), dim=1)

    #     return idx

# %%
params = ModelArgs

# %% [markdown]
# # Dataset Generation

# %%
def generate_dataset(path_location):

    input_batches = []
    output_batches = []

    all_files = os.listdir(path_location)
    file_paths = [os.path.join(path_location, file) for file in all_files]

    for file in file_paths :
        df = pd.read_csv(file, delimiter=';', encoding='ISO-8859-1')
        df = df[req_parameters]
        df['SoC [%]'] = df['SoC [%]'].shift(1)
        df = df.rename(columns={'SoC [%]' : 'prevsoc'})
        df.dropna(inplace=True)

        input_tensors = []
        output_tensors = []
        start_index = 0
        for index, row in df.iterrows():
            if index == (len(df) - 1):
                break
            if (index + 1) % params.max_seq_len == 0:
                input_tensor = torch.tensor(df.iloc[start_index : index + 1].values, dtype=torch.float32).to(device)
                output_tensor = torch.tensor(df.iloc[index+1, df.columns.get_loc('prevsoc')], dtype=torch.float32).to(device)

                input_tensors.append(input_tensor)
                output_tensors.append(output_tensor)

                start_index = index + 1

        combined = list(zip(input_tensors, output_tensors))
        random.shuffle(combined)
        input_tensors, output_tensors = zip(*combined)

        temp_input_batches = []
        temp_output_batches = []

        for i in range(0, len(input_tensors), params.max_batch_size):
            input_batch =  torch.stack(input_tensors[i:i+params.max_batch_size])
            temp_input_batches.append(input_batch)

            output_batch =  torch.stack(output_tensors[i:i+params.max_batch_size])
            temp_output_batches.append(output_batch)

        temp_input_batches = temp_input_batches[:-1]
        temp_output_batches = temp_output_batches[:-1]

        input_batches += temp_input_batches
        output_batches += temp_output_batches

    n = len(input_batches)
    split_index = int(params.split_ratio * n)

    input_train_list = input_batches[:split_index]
    input_val_list = input_batches[split_index:]

    output_train_list = output_batches[:split_index]
    output_val_list = output_batches[split_index:]

    return input_train_list, input_val_list, output_train_list, output_val_list

path_location = 'summer_dataset'
input_train_list, input_val_list, output_train_list, output_val_list = generate_dataset(path_location)

train_data = len(input_train_list)
val_data = len(input_val_list)

print(f'Size of training data : {train_data}')
print(f'Size of validation data : {val_data}')
# Out:
# Size of training data : 232
# Size of validation data : 58

# %% [markdown]
# # Model Training

# %%
model = Transformer(params).to(device)

print(count_parameters(model))
# Out:
# 1705984

# %%
class LogCoshLoss(torch.nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, y_t, y_prime_t):
        ey_t = y_t - y_prime_t
        return torch.mean(torch.log(torch.cosh(ey_t + 1e-12)))

# warmup_steps = 500
class Scheduler(_LRScheduler):
    def __init__(self, optimizer: Optimizer, dim_embed: int, warmup_steps: int, last_epoch: int=-1, verbose: bool=False) -> None:
        self.dim_embed = dim_embed
        self.warmup_steps = warmup_steps
        self.num_param_groups = len(optimizer.param_groups)

        super().__init__(optimizer, last_epoch, verbose)
        
    def get_lr(self) -> float:
        lr = calc_lr(self._step_count, self.dim_embed, self.warmup_steps)
        return [lr] * self.num_param_groups

def calc_lr(step, dim_embed, warmup_steps):
    return dim_embed**(-0.5) * min(step**(-0.5), step * warmup_steps**(-1.5))

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), betas=(0.9, 0.98), eps=1.0e-9)
scheduler = Scheduler(optimizer, params.dim, warmup_steps=20)

# %% [markdown]
# Training Cycle

# %%
training_loss = []
validation_loss = []
learning_rate = []

print_steps = 100

for i in range(params.epochs):
    train_loss = 0
    for j in range(len(input_train_list)):
        input_batch = input_train_list[j]
        output_batch = output_train_list[j]

        optimizer.zero_grad()
        calculated_output = model(input_batch)

        loss = criterion(output_batch, calculated_output)
        train_loss += loss.item()

        loss.backward()
        optimizer.step()

    val_loss = 0

    scheduler.step()

    with torch.no_grad():
        for j in range(len(input_val_list)):
            input_batch = input_val_list[j]
            output_batch = output_val_list[j]

            calculated_output = model(input_batch)

            loss = criterion(output_batch, calculated_output)
            val_loss += loss.item()

    temp_training_loss = train_loss / train_data
    temp_validation_loss = val_loss / val_data
    current_lr = optimizer.param_groups[0]['lr']

    writer.add_scalar('Training loss', temp_training_loss)
    writer.add_scalar('Validation Loss', temp_validation_loss)
    writer.add_scalar('Learning Rate', current_lr)

    print(f'epoch : {i+1}, Training loss : {temp_training_loss:.3f}, Validation loss : {temp_validation_loss:.3f}, Learning rate : {current_lr:.3f}')
    
    training_loss.append(temp_training_loss)
    validation_loss.append(temp_validation_loss)
    learning_rate.append(current_lr)
# Out:
# epoch : 1, Training loss : 2833.441, Validation loss : 1286.399, Learning rate : 0.001
# epoch : 2, Training loss : 325.616, Validation loss : 49.414, Learning rate : 0.002
# epoch : 3, Training loss : 162.410, Validation loss : 65.890, Learning rate : 0.003
# epoch : 4, Training loss : 150.597, Validation loss : 71.988, Learning rate : 0.003
# epoch : 5, Training loss : 151.350, Validation loss : 74.075, Learning rate : 0.004
# epoch : 6, Training loss : 154.821, Validation loss : 79.850, Learning rate : 0.005
# epoch : 7, Training loss : 153.328, Validation loss : 83.635, Learning rate : 0.006
# epoch : 8, Training loss : 159.628, Validation loss : 85.261, Learning rate : 0.006
# epoch : 9, Training loss : 167.197, Validation loss : 85.950, Learning rate : 0.007
# epoch : 10, Training loss : 165.826, Validation loss : 82.565, Learning rate : 0.008
# epoch : 11, Training loss : 171.005, Validation loss : 82.075, Learning rate : 0.008
# epoch : 12, Training loss : 165.897, Validation loss : 58.977, Learning rate : 0.009
# epoch : 13, Training loss : 179.883, Validation loss : 83.256, Learning rate : 0.010
# epoch : 14, Training loss : 174.561, Validation loss : 86.165, Learning rate : 0.010
# epoch : 15, Training loss : 182.820, Validation loss : 88.403, Learning rate : 0.011
# epoch : 16, Training loss : 174.767, Validation loss : 76.689, Learning rate : 0.012
# epoch : 17, Training loss : 178.030, Validation loss : 77.125, Learning rate : 0.013
# epoch : 18, Training loss : 177.261, Validation loss : 79.662, Learning rate : 0.013
# epoch : 19, Training loss : 176.703, Validation loss : 80.707, Learning rate : 0.014
# epoch : 20, Training loss : 174.860, Validation loss : 57.755, Learning rate : 0.014
# epoch : 21, Training loss : 172.285, Validation loss : 90.006, Learning rate : 0.013
# epoch : 22, Training loss : 171.054, Validation loss : 84.493, Learning rate : 0.013
# epoch : 23, Training loss : 165.659, Validation loss : 94.187, Learning rate : 0.013
# epoch : 24, Training loss : 168.889, Validation loss : 89.604, Learning rate : 0.013
# epoch : 25, Training loss : 163.504, Validation loss : 88.923, Learning rate : 0.012
# epoch : 26, Training loss : 162.424, Validation loss : 83.462, Learning rate : 0.012
# epoch : 27, Training loss : 159.477, Validation loss : 95.643, Learning rate : 0.012
# epoch : 28, Training loss : 158.624, Validation loss : 100.397, Learning rate : 0.012
# epoch : 29, Training loss : 158.749, Validation loss : 80.258, Learning rate : 0.011
# epoch : 30, Training loss : 158.599, Validation loss : 84.618, Learning rate : 0.011
# epoch : 31, Training loss : 157.303, Validation loss : 80.425, Learning rate : 0.011
# epoch : 32, Training loss : 153.382, Validation loss : 88.516, Learning rate : 0.011
# epoch : 33, Training loss : 152.566, Validation loss : 83.493, Learning rate : 0.011
# epoch : 34, Training loss : 150.877, Validation loss : 80.912, Learning rate : 0.011
# epoch : 35, Training loss : 150.805, Validation loss : 80.950, Learning rate : 0.010
# epoch : 36, Training loss : 151.417, Validation loss : 79.994, Learning rate : 0.010
# epoch : 37, Training loss : 147.223, Validation loss : 81.314, Learning rate : 0.010
# epoch : 38, Training loss : 144.645, Validation loss : 79.486, Learning rate : 0.010
# epoch : 39, Training loss : 146.630, Validation loss : 78.913, Learning rate : 0.010
# epoch : 40, Training loss : 146.502, Validation loss : 77.656, Learning rate : 0.010
# epoch : 41, Training loss : 132.548, Validation loss : 75.465, Learning rate : 0.010
# epoch : 42, Training loss : 133.021, Validation loss : 77.758, Learning rate : 0.010
# epoch : 43, Training loss : 132.023, Validation loss : 76.570, Learning rate : 0.009
# epoch : 44, Training loss : 134.412, Validation loss : 87.681, Learning rate : 0.009
# epoch : 45, Training loss : 128.331, Validation loss : 80.720, Learning rate : 0.009
# epoch : 46, Training loss : 131.685, Validation loss : 73.797, Learning rate : 0.009
# epoch : 47, Training loss : 127.463, Validation loss : 71.818, Learning rate : 0.009
# epoch : 48, Training loss : 139.079, Validation loss : 74.231, Learning rate : 0.009
# epoch : 49, Training loss : 132.284, Validation loss : 75.958, Learning rate : 0.009
# epoch : 50, Training loss : 123.380, Validation loss : 76.952, Learning rate : 0.009
# epoch : 51, Training loss : 125.206, Validation loss : 72.432, Learning rate : 0.009
# epoch : 52, Training loss : 126.247, Validation loss : 73.431, Learning rate : 0.009
# epoch : 53, Training loss : 124.456, Validation loss : 71.437, Learning rate : 0.009
# epoch : 54, Training loss : 126.616, Validation loss : 77.033, Learning rate : 0.008
# epoch : 55, Training loss : 120.905, Validation loss : 69.141, Learning rate : 0.008
# epoch : 56, Training loss : 117.669, Validation loss : 68.248, Learning rate : 0.008
# epoch : 57, Training loss : 118.548, Validation loss : 70.952, Learning rate : 0.008
# epoch : 58, Training loss : 113.341, Validation loss : 67.455, Learning rate : 0.008
# epoch : 59, Training loss : 110.446, Validation loss : 69.383, Learning rate : 0.008
# epoch : 60, Training loss : 112.173, Validation loss : 62.845, Learning rate : 0.008
# epoch : 61, Training loss : 107.635, Validation loss : 72.200, Learning rate : 0.008
# epoch : 62, Training loss : 109.164, Validation loss : 65.949, Learning rate : 0.008
# epoch : 63, Training loss : 107.823, Validation loss : 63.045, Learning rate : 0.008
# epoch : 64, Training loss : 100.091, Validation loss : 64.803, Learning rate : 0.008
# epoch : 65, Training loss : 102.426, Validation loss : 66.062, Learning rate : 0.008
# epoch : 66, Training loss : 93.852, Validation loss : 65.342, Learning rate : 0.008
# epoch : 67, Training loss : 101.575, Validation loss : 60.847, Learning rate : 0.008
# epoch : 68, Training loss : 88.970, Validation loss : 63.580, Learning rate : 0.008
# epoch : 69, Training loss : 79.127, Validation loss : 61.970, Learning rate : 0.007
# epoch : 70, Training loss : 80.202, Validation loss : 62.066, Learning rate : 0.007
# epoch : 71, Training loss : 75.487, Validation loss : 64.600, Learning rate : 0.007
# epoch : 72, Training loss : 82.259, Validation loss : 62.766, Learning rate : 0.007
# epoch : 73, Training loss : 69.994, Validation loss : 65.791, Learning rate : 0.007
# epoch : 74, Training loss : 69.688, Validation loss : 65.877, Learning rate : 0.007
# epoch : 75, Training loss : 65.263, Validation loss : 63.666, Learning rate : 0.007
# epoch : 76, Training loss : 63.461, Validation loss : 59.448, Learning rate : 0.007
# epoch : 77, Training loss : 59.320, Validation loss : 54.319, Learning rate : 0.007
# epoch : 78, Training loss : 55.571, Validation loss : 58.295, Learning rate : 0.007
# epoch : 79, Training loss : 60.827, Validation loss : 59.110, Learning rate : 0.007
# epoch : 80, Training loss : 64.204, Validation loss : 52.459, Learning rate : 0.007
# epoch : 81, Training loss : 51.965, Validation loss : 54.309, Learning rate : 0.007
# epoch : 82, Training loss : 35.835, Validation loss : 25.500, Learning rate : 0.007
# epoch : 83, Training loss : 38.075, Validation loss : 28.510, Learning rate : 0.007
# epoch : 84, Training loss : 48.220, Validation loss : 25.562, Learning rate : 0.007
# epoch : 85, Training loss : 47.857, Validation loss : 23.575, Learning rate : 0.007
# epoch : 86, Training loss : 47.623, Validation loss : 18.529, Learning rate : 0.007
# epoch : 87, Training loss : 33.534, Validation loss : 19.280, Learning rate : 0.007
# epoch : 88, Training loss : 41.923, Validation loss : 37.430, Learning rate : 0.007
# epoch : 89, Training loss : 29.629, Validation loss : 15.935, Learning rate : 0.007
# epoch : 90, Training loss : 26.886, Validation loss : 17.173, Learning rate : 0.007
# epoch : 91, Training loss : 41.101, Validation loss : 15.203, Learning rate : 0.007
# epoch : 92, Training loss : 26.312, Validation loss : 13.974, Learning rate : 0.006
# epoch : 93, Training loss : 21.064, Validation loss : 15.370, Learning rate : 0.006
# epoch : 94, Training loss : 22.855, Validation loss : 10.317, Learning rate : 0.006
# epoch : 95, Training loss : 22.241, Validation loss : 14.229, Learning rate : 0.006
# epoch : 96, Training loss : 18.533, Validation loss : 12.184, Learning rate : 0.006
# epoch : 97, Training loss : 17.798, Validation loss : 11.922, Learning rate : 0.006
# epoch : 98, Training loss : 19.064, Validation loss : 13.256, Learning rate : 0.006
# epoch : 99, Training loss : 23.794, Validation loss : 13.424, Learning rate : 0.006
# epoch : 100, Training loss : 19.507, Validation loss : 10.781, Learning rate : 0.006
# epoch : 101, Training loss : 15.941, Validation loss : 7.675, Learning rate : 0.006
# epoch : 102, Training loss : 22.237, Validation loss : 9.781, Learning rate : 0.006
# epoch : 103, Training loss : 13.229, Validation loss : 13.065, Learning rate : 0.006
# epoch : 104, Training loss : 14.499, Validation loss : 11.420, Learning rate : 0.006
# epoch : 105, Training loss : 13.480, Validation loss : 7.610, Learning rate : 0.006
# epoch : 106, Training loss : 9.610, Validation loss : 8.898, Learning rate : 0.006
# epoch : 107, Training loss : 10.420, Validation loss : 5.019, Learning rate : 0.006
# epoch : 108, Training loss : 11.260, Validation loss : 11.088, Learning rate : 0.006
# epoch : 109, Training loss : 9.870, Validation loss : 15.824, Learning rate : 0.006
# epoch : 110, Training loss : 10.732, Validation loss : 5.145, Learning rate : 0.006
# epoch : 111, Training loss : 6.974, Validation loss : 8.811, Learning rate : 0.006
# epoch : 112, Training loss : 10.168, Validation loss : 8.440, Learning rate : 0.006
# epoch : 113, Training loss : 7.984, Validation loss : 10.448, Learning rate : 0.006
# epoch : 114, Training loss : 9.154, Validation loss : 5.007, Learning rate : 0.006
# epoch : 115, Training loss : 7.623, Validation loss : 5.071, Learning rate : 0.006
# epoch : 116, Training loss : 9.156, Validation loss : 6.171, Learning rate : 0.006
# epoch : 117, Training loss : 8.724, Validation loss : 4.495, Learning rate : 0.006
# epoch : 118, Training loss : 6.726, Validation loss : 3.147, Learning rate : 0.006
# epoch : 119, Training loss : 5.084, Validation loss : 8.691, Learning rate : 0.006
# epoch : 120, Training loss : 5.962, Validation loss : 4.069, Learning rate : 0.006
# epoch : 121, Training loss : 5.188, Validation loss : 4.106, Learning rate : 0.006
# epoch : 122, Training loss : 5.386, Validation loss : 5.459, Learning rate : 0.006
# epoch : 123, Training loss : 7.454, Validation loss : 2.925, Learning rate : 0.006
# epoch : 124, Training loss : 5.934, Validation loss : 6.020, Learning rate : 0.006
# epoch : 125, Training loss : 5.399, Validation loss : 3.459, Learning rate : 0.006
# epoch : 126, Training loss : 5.638, Validation loss : 3.738, Learning rate : 0.006
# epoch : 127, Training loss : 5.190, Validation loss : 4.829, Learning rate : 0.006
# epoch : 128, Training loss : 4.316, Validation loss : 2.569, Learning rate : 0.006
# epoch : 129, Training loss : 3.346, Validation loss : 3.433, Learning rate : 0.005
# epoch : 130, Training loss : 4.835, Validation loss : 2.555, Learning rate : 0.005
# epoch : 131, Training loss : 4.493, Validation loss : 8.336, Learning rate : 0.005
# epoch : 132, Training loss : 4.279, Validation loss : 4.165, Learning rate : 0.005
# epoch : 133, Training loss : 5.513, Validation loss : 4.680, Learning rate : 0.005
# epoch : 134, Training loss : 4.467, Validation loss : 2.921, Learning rate : 0.005
# epoch : 135, Training loss : 5.629, Validation loss : 5.204, Learning rate : 0.005
# epoch : 136, Training loss : 4.008, Validation loss : 3.163, Learning rate : 0.005
# epoch : 137, Training loss : 4.547, Validation loss : 2.171, Learning rate : 0.005
# epoch : 138, Training loss : 4.555, Validation loss : 3.585, Learning rate : 0.005
# epoch : 139, Training loss : 3.849, Validation loss : 2.337, Learning rate : 0.005
# epoch : 140, Training loss : 4.716, Validation loss : 2.974, Learning rate : 0.005
# epoch : 141, Training loss : 4.844, Validation loss : 2.188, Learning rate : 0.005
# epoch : 142, Training loss : 6.295, Validation loss : 2.724, Learning rate : 0.005
# epoch : 143, Training loss : 4.779, Validation loss : 4.255, Learning rate : 0.005
# epoch : 144, Training loss : 4.911, Validation loss : 3.222, Learning rate : 0.005
# epoch : 145, Training loss : 3.793, Validation loss : 2.878, Learning rate : 0.005
# epoch : 146, Training loss : 4.023, Validation loss : 2.327, Learning rate : 0.005
# epoch : 147, Training loss : 3.879, Validation loss : 2.751, Learning rate : 0.005
# epoch : 148, Training loss : 3.517, Validation loss : 4.919, Learning rate : 0.005
# epoch : 149, Training loss : 3.128, Validation loss : 2.264, Learning rate : 0.005
# epoch : 150, Training loss : 2.734, Validation loss : 2.069, Learning rate : 0.005
# epoch : 151, Training loss : 3.039, Validation loss : 5.612, Learning rate : 0.005
# epoch : 152, Training loss : 4.796, Validation loss : 2.862, Learning rate : 0.005
# epoch : 153, Training loss : 2.844, Validation loss : 3.196, Learning rate : 0.005
# epoch : 154, Training loss : 3.406, Validation loss : 2.216, Learning rate : 0.005
# epoch : 155, Training loss : 3.823, Validation loss : 1.681, Learning rate : 0.005
# epoch : 156, Training loss : 2.886, Validation loss : 2.123, Learning rate : 0.005
# epoch : 157, Training loss : 3.188, Validation loss : 1.542, Learning rate : 0.005
# epoch : 158, Training loss : 2.909, Validation loss : 3.830, Learning rate : 0.005
# epoch : 159, Training loss : 2.541, Validation loss : 1.865, Learning rate : 0.005
# epoch : 160, Training loss : 2.941, Validation loss : 2.142, Learning rate : 0.005
# epoch : 161, Training loss : 2.905, Validation loss : 3.200, Learning rate : 0.005
# epoch : 162, Training loss : 3.085, Validation loss : 4.371, Learning rate : 0.005
# epoch : 163, Training loss : 3.005, Validation loss : 2.227, Learning rate : 0.005
# epoch : 164, Training loss : 2.532, Validation loss : 2.734, Learning rate : 0.005
# epoch : 165, Training loss : 3.697, Validation loss : 4.962, Learning rate : 0.005
# epoch : 166, Training loss : 3.336, Validation loss : 1.778, Learning rate : 0.005
# epoch : 167, Training loss : 6.622, Validation loss : 2.213, Learning rate : 0.005
# epoch : 168, Training loss : 2.818, Validation loss : 2.125, Learning rate : 0.005
# epoch : 169, Training loss : 3.443, Validation loss : 8.844, Learning rate : 0.005
# epoch : 170, Training loss : 3.033, Validation loss : 1.676, Learning rate : 0.005
# epoch : 171, Training loss : 2.399, Validation loss : 5.602, Learning rate : 0.005
# epoch : 172, Training loss : 2.867, Validation loss : 12.093, Learning rate : 0.005
# epoch : 173, Training loss : 3.153, Validation loss : 1.592, Learning rate : 0.005
# epoch : 174, Training loss : 3.044, Validation loss : 2.782, Learning rate : 0.005
# epoch : 175, Training loss : 2.512, Validation loss : 2.488, Learning rate : 0.005
# epoch : 176, Training loss : 2.381, Validation loss : 1.519, Learning rate : 0.005
# epoch : 177, Training loss : 2.284, Validation loss : 1.262, Learning rate : 0.005
# epoch : 178, Training loss : 2.610, Validation loss : 1.425, Learning rate : 0.005
# epoch : 179, Training loss : 2.128, Validation loss : 1.839, Learning rate : 0.005
# epoch : 180, Training loss : 2.640, Validation loss : 1.691, Learning rate : 0.005
# epoch : 181, Training loss : 2.984, Validation loss : 1.904, Learning rate : 0.005
# epoch : 182, Training loss : 3.006, Validation loss : 3.178, Learning rate : 0.005
# epoch : 183, Training loss : 2.929, Validation loss : 1.820, Learning rate : 0.005
# epoch : 184, Training loss : 2.644, Validation loss : 6.404, Learning rate : 0.005
# epoch : 185, Training loss : 2.365, Validation loss : 1.652, Learning rate : 0.005
# epoch : 186, Training loss : 2.276, Validation loss : 1.421, Learning rate : 0.005
# epoch : 187, Training loss : 2.561, Validation loss : 1.691, Learning rate : 0.005
# epoch : 188, Training loss : 2.515, Validation loss : 2.518, Learning rate : 0.005
# epoch : 189, Training loss : 3.339, Validation loss : 4.811, Learning rate : 0.005
# epoch : 190, Training loss : 2.902, Validation loss : 1.552, Learning rate : 0.005
# epoch : 191, Training loss : 1.943, Validation loss : 1.462, Learning rate : 0.005
# epoch : 192, Training loss : 2.741, Validation loss : 2.629, Learning rate : 0.004
# epoch : 193, Training loss : 2.735, Validation loss : 2.930, Learning rate : 0.004
# epoch : 194, Training loss : 1.809, Validation loss : 1.427, Learning rate : 0.004
# epoch : 195, Training loss : 3.227, Validation loss : 3.373, Learning rate : 0.004
# epoch : 196, Training loss : 2.288, Validation loss : 2.106, Learning rate : 0.004
# epoch : 197, Training loss : 2.327, Validation loss : 5.667, Learning rate : 0.004
# epoch : 198, Training loss : 2.597, Validation loss : 2.020, Learning rate : 0.004
# epoch : 199, Training loss : 2.147, Validation loss : 2.414, Learning rate : 0.004
# epoch : 200, Training loss : 2.853, Validation loss : 2.199, Learning rate : 0.004
# epoch : 201, Training loss : 2.522, Validation loss : 1.476, Learning rate : 0.004
# epoch : 202, Training loss : 2.417, Validation loss : 1.525, Learning rate : 0.004
# epoch : 203, Training loss : 2.705, Validation loss : 3.253, Learning rate : 0.004
# epoch : 204, Training loss : 2.069, Validation loss : 5.220, Learning rate : 0.004
# epoch : 205, Training loss : 2.030, Validation loss : 3.532, Learning rate : 0.004
# epoch : 206, Training loss : 2.920, Validation loss : 6.567, Learning rate : 0.004
# epoch : 207, Training loss : 2.294, Validation loss : 7.362, Learning rate : 0.004
# epoch : 208, Training loss : 2.157, Validation loss : 2.337, Learning rate : 0.004
# epoch : 209, Training loss : 2.550, Validation loss : 1.920, Learning rate : 0.004
# epoch : 210, Training loss : 2.940, Validation loss : 1.372, Learning rate : 0.004
# epoch : 211, Training loss : 2.473, Validation loss : 1.817, Learning rate : 0.004
# epoch : 212, Training loss : 2.622, Validation loss : 1.783, Learning rate : 0.004
# epoch : 213, Training loss : 2.186, Validation loss : 1.103, Learning rate : 0.004
# epoch : 214, Training loss : 1.734, Validation loss : 1.484, Learning rate : 0.004
# epoch : 215, Training loss : 1.730, Validation loss : 2.400, Learning rate : 0.004
# epoch : 216, Training loss : 1.867, Validation loss : 1.315, Learning rate : 0.004
# epoch : 217, Training loss : 1.811, Validation loss : 2.295, Learning rate : 0.004
# epoch : 218, Training loss : 2.306, Validation loss : 4.753, Learning rate : 0.004
# epoch : 219, Training loss : 2.298, Validation loss : 4.152, Learning rate : 0.004
# epoch : 220, Training loss : 2.612, Validation loss : 1.719, Learning rate : 0.004
# epoch : 221, Training loss : 2.256, Validation loss : 2.583, Learning rate : 0.004
# epoch : 222, Training loss : 2.412, Validation loss : 4.231, Learning rate : 0.004
# epoch : 223, Training loss : 2.487, Validation loss : 2.871, Learning rate : 0.004
# epoch : 224, Training loss : 2.304, Validation loss : 4.206, Learning rate : 0.004
# epoch : 225, Training loss : 2.501, Validation loss : 1.208, Learning rate : 0.004
# epoch : 226, Training loss : 2.157, Validation loss : 1.916, Learning rate : 0.004
# epoch : 227, Training loss : 2.112, Validation loss : 1.599, Learning rate : 0.004
# epoch : 228, Training loss : 2.622, Validation loss : 1.682, Learning rate : 0.004
# epoch : 229, Training loss : 3.300, Validation loss : 3.135, Learning rate : 0.004
# epoch : 230, Training loss : 2.693, Validation loss : 2.252, Learning rate : 0.004
# epoch : 231, Training loss : 2.376, Validation loss : 1.715, Learning rate : 0.004
# epoch : 232, Training loss : 2.811, Validation loss : 2.725, Learning rate : 0.004
# epoch : 233, Training loss : 2.067, Validation loss : 1.619, Learning rate : 0.004
# epoch : 234, Training loss : 2.233, Validation loss : 3.739, Learning rate : 0.004
# epoch : 235, Training loss : 1.507, Validation loss : 1.064, Learning rate : 0.004
# epoch : 236, Training loss : 2.848, Validation loss : 1.820, Learning rate : 0.004
# epoch : 237, Training loss : 2.031, Validation loss : 1.325, Learning rate : 0.004
# epoch : 238, Training loss : 2.028, Validation loss : 1.278, Learning rate : 0.004
# epoch : 239, Training loss : 2.401, Validation loss : 1.658, Learning rate : 0.004
# epoch : 240, Training loss : 2.313, Validation loss : 1.281, Learning rate : 0.004
# epoch : 241, Training loss : 2.384, Validation loss : 3.773, Learning rate : 0.004
# epoch : 242, Training loss : 2.997, Validation loss : 1.513, Learning rate : 0.004
# epoch : 243, Training loss : 2.353, Validation loss : 1.344, Learning rate : 0.004
# epoch : 244, Training loss : 2.311, Validation loss : 2.022, Learning rate : 0.004
# epoch : 245, Training loss : 2.201, Validation loss : 1.500, Learning rate : 0.004
# epoch : 246, Training loss : 2.065, Validation loss : 1.401, Learning rate : 0.004
# epoch : 247, Training loss : 1.866, Validation loss : 1.412, Learning rate : 0.004
# epoch : 248, Training loss : 2.084, Validation loss : 1.173, Learning rate : 0.004
# epoch : 249, Training loss : 2.060, Validation loss : 2.904, Learning rate : 0.004
# epoch : 250, Training loss : 2.852, Validation loss : 1.893, Learning rate : 0.004
# epoch : 251, Training loss : 2.568, Validation loss : 1.058, Learning rate : 0.004
# epoch : 252, Training loss : 2.043, Validation loss : 2.485, Learning rate : 0.004
# epoch : 253, Training loss : 2.459, Validation loss : 1.309, Learning rate : 0.004
# epoch : 254, Training loss : 1.920, Validation loss : 3.382, Learning rate : 0.004
# epoch : 255, Training loss : 2.451, Validation loss : 1.117, Learning rate : 0.004
# epoch : 256, Training loss : 2.311, Validation loss : 0.972, Learning rate : 0.004
# epoch : 257, Training loss : 1.666, Validation loss : 1.844, Learning rate : 0.004
# epoch : 258, Training loss : 1.499, Validation loss : 1.274, Learning rate : 0.004
# epoch : 259, Training loss : 1.852, Validation loss : 1.192, Learning rate : 0.004
# epoch : 260, Training loss : 1.431, Validation loss : 6.054, Learning rate : 0.004
# epoch : 261, Training loss : 1.993, Validation loss : 1.173, Learning rate : 0.004
# epoch : 262, Training loss : 2.164, Validation loss : 1.337, Learning rate : 0.004
# epoch : 263, Training loss : 2.066, Validation loss : 3.766, Learning rate : 0.004
# epoch : 264, Training loss : 2.042, Validation loss : 1.418, Learning rate : 0.004
# epoch : 265, Training loss : 1.810, Validation loss : 2.733, Learning rate : 0.004
# epoch : 266, Training loss : 1.899, Validation loss : 4.447, Learning rate : 0.004
# epoch : 267, Training loss : 2.081, Validation loss : 1.895, Learning rate : 0.004
# epoch : 268, Training loss : 1.504, Validation loss : 0.995, Learning rate : 0.004
# epoch : 269, Training loss : 1.541, Validation loss : 1.209, Learning rate : 0.004
# epoch : 270, Training loss : 1.978, Validation loss : 1.364, Learning rate : 0.004
# epoch : 271, Training loss : 1.518, Validation loss : 1.188, Learning rate : 0.004
# epoch : 272, Training loss : 1.498, Validation loss : 1.755, Learning rate : 0.004
# epoch : 273, Training loss : 1.859, Validation loss : 1.111, Learning rate : 0.004
# epoch : 274, Training loss : 1.528, Validation loss : 1.737, Learning rate : 0.004
# epoch : 275, Training loss : 1.514, Validation loss : 1.427, Learning rate : 0.004
# epoch : 276, Training loss : 1.420, Validation loss : 0.999, Learning rate : 0.004
# epoch : 277, Training loss : 1.391, Validation loss : 3.678, Learning rate : 0.004
# epoch : 278, Training loss : 1.652, Validation loss : 4.037, Learning rate : 0.004
# epoch : 279, Training loss : 1.694, Validation loss : 1.981, Learning rate : 0.004
# epoch : 280, Training loss : 1.600, Validation loss : 1.246, Learning rate : 0.004
# epoch : 281, Training loss : 1.576, Validation loss : 1.895, Learning rate : 0.004
# epoch : 282, Training loss : 2.132, Validation loss : 1.861, Learning rate : 0.004
# epoch : 283, Training loss : 1.425, Validation loss : 2.238, Learning rate : 0.004
# epoch : 284, Training loss : 1.658, Validation loss : 1.093, Learning rate : 0.004
# epoch : 285, Training loss : 1.792, Validation loss : 3.280, Learning rate : 0.004
# epoch : 286, Training loss : 1.610, Validation loss : 1.923, Learning rate : 0.004
# epoch : 287, Training loss : 1.523, Validation loss : 2.123, Learning rate : 0.004
# epoch : 288, Training loss : 1.623, Validation loss : 1.324, Learning rate : 0.004
# epoch : 289, Training loss : 1.277, Validation loss : 1.039, Learning rate : 0.004
# epoch : 290, Training loss : 1.343, Validation loss : 4.299, Learning rate : 0.004
# epoch : 291, Training loss : 1.776, Validation loss : 2.008, Learning rate : 0.004
# epoch : 292, Training loss : 1.655, Validation loss : 1.242, Learning rate : 0.004
# epoch : 293, Training loss : 1.667, Validation loss : 1.449, Learning rate : 0.004
# epoch : 294, Training loss : 1.331, Validation loss : 1.403, Learning rate : 0.004
# epoch : 295, Training loss : 1.383, Validation loss : 0.916, Learning rate : 0.004
# epoch : 296, Training loss : 1.697, Validation loss : 8.556, Learning rate : 0.004
# epoch : 297, Training loss : 1.688, Validation loss : 2.597, Learning rate : 0.004
# epoch : 298, Training loss : 1.368, Validation loss : 1.036, Learning rate : 0.004
# epoch : 299, Training loss : 1.623, Validation loss : 5.043, Learning rate : 0.004
# epoch : 300, Training loss : 1.385, Validation loss : 2.032, Learning rate : 0.004
# epoch : 301, Training loss : 1.295, Validation loss : 1.059, Learning rate : 0.004
# epoch : 302, Training loss : 1.717, Validation loss : 2.163, Learning rate : 0.004
# epoch : 303, Training loss : 1.398, Validation loss : 1.711, Learning rate : 0.004
# epoch : 304, Training loss : 1.833, Validation loss : 1.626, Learning rate : 0.004
# epoch : 305, Training loss : 1.531, Validation loss : 0.981, Learning rate : 0.004
# epoch : 306, Training loss : 1.426, Validation loss : 2.977, Learning rate : 0.004
# epoch : 307, Training loss : 2.030, Validation loss : 3.740, Learning rate : 0.004
# epoch : 308, Training loss : 1.373, Validation loss : 0.979, Learning rate : 0.004
# epoch : 309, Training loss : 1.785, Validation loss : 1.175, Learning rate : 0.004
# epoch : 310, Training loss : 1.304, Validation loss : 1.969, Learning rate : 0.004
# epoch : 311, Training loss : 1.784, Validation loss : 1.253, Learning rate : 0.004
# epoch : 312, Training loss : 1.451, Validation loss : 1.292, Learning rate : 0.004
# epoch : 313, Training loss : 1.532, Validation loss : 1.539, Learning rate : 0.004
# epoch : 314, Training loss : 1.568, Validation loss : 1.002, Learning rate : 0.004
# epoch : 315, Training loss : 1.273, Validation loss : 1.457, Learning rate : 0.004
# epoch : 316, Training loss : 1.200, Validation loss : 4.523, Learning rate : 0.004
# epoch : 317, Training loss : 1.350, Validation loss : 1.257, Learning rate : 0.004
# epoch : 318, Training loss : 1.525, Validation loss : 2.998, Learning rate : 0.003
# epoch : 319, Training loss : 1.693, Validation loss : 1.172, Learning rate : 0.003
# epoch : 320, Training loss : 1.970, Validation loss : 5.210, Learning rate : 0.003
# epoch : 321, Training loss : 1.880, Validation loss : 1.108, Learning rate : 0.003
# epoch : 322, Training loss : 1.667, Validation loss : 0.934, Learning rate : 0.003
# epoch : 323, Training loss : 1.241, Validation loss : 1.017, Learning rate : 0.003
# epoch : 324, Training loss : 1.370, Validation loss : 1.560, Learning rate : 0.003
# epoch : 325, Training loss : 1.337, Validation loss : 1.012, Learning rate : 0.003
# epoch : 326, Training loss : 1.299, Validation loss : 1.396, Learning rate : 0.003
# epoch : 327, Training loss : 1.420, Validation loss : 1.018, Learning rate : 0.003
# epoch : 328, Training loss : 1.762, Validation loss : 0.961, Learning rate : 0.003
# epoch : 329, Training loss : 1.396, Validation loss : 2.443, Learning rate : 0.003
# epoch : 330, Training loss : 1.599, Validation loss : 3.139, Learning rate : 0.003
# epoch : 331, Training loss : 1.804, Validation loss : 2.980, Learning rate : 0.003
# epoch : 332, Training loss : 1.321, Validation loss : 0.988, Learning rate : 0.003
# epoch : 333, Training loss : 1.508, Validation loss : 1.525, Learning rate : 0.003
# epoch : 334, Training loss : 1.342, Validation loss : 2.432, Learning rate : 0.003
# epoch : 335, Training loss : 1.379, Validation loss : 1.699, Learning rate : 0.003
# epoch : 336, Training loss : 1.112, Validation loss : 0.856, Learning rate : 0.003
# epoch : 337, Training loss : 1.142, Validation loss : 1.069, Learning rate : 0.003
# epoch : 338, Training loss : 1.234, Validation loss : 1.214, Learning rate : 0.003
# epoch : 339, Training loss : 1.373, Validation loss : 1.880, Learning rate : 0.003
# epoch : 340, Training loss : 1.197, Validation loss : 1.060, Learning rate : 0.003
# epoch : 341, Training loss : 1.299, Validation loss : 3.336, Learning rate : 0.003
# epoch : 342, Training loss : 1.263, Validation loss : 1.035, Learning rate : 0.003
# epoch : 343, Training loss : 1.447, Validation loss : 1.447, Learning rate : 0.003
# epoch : 344, Training loss : 1.582, Validation loss : 0.801, Learning rate : 0.003
# epoch : 345, Training loss : 1.118, Validation loss : 0.798, Learning rate : 0.003
# epoch : 346, Training loss : 1.429, Validation loss : 4.291, Learning rate : 0.003
# epoch : 347, Training loss : 1.117, Validation loss : 0.729, Learning rate : 0.003
# epoch : 348, Training loss : 1.084, Validation loss : 0.789, Learning rate : 0.003
# epoch : 349, Training loss : 1.435, Validation loss : 2.079, Learning rate : 0.003
# epoch : 350, Training loss : 1.634, Validation loss : 2.244, Learning rate : 0.003
# epoch : 351, Training loss : 1.916, Validation loss : 0.726, Learning rate : 0.003
# epoch : 352, Training loss : 1.519, Validation loss : 0.916, Learning rate : 0.003
# epoch : 353, Training loss : 1.110, Validation loss : 0.930, Learning rate : 0.003
# epoch : 354, Training loss : 1.334, Validation loss : 2.650, Learning rate : 0.003
# epoch : 355, Training loss : 1.207, Validation loss : 0.884, Learning rate : 0.003
# epoch : 356, Training loss : 1.668, Validation loss : 0.762, Learning rate : 0.003
# epoch : 357, Training loss : 1.221, Validation loss : 0.934, Learning rate : 0.003
# epoch : 358, Training loss : 1.409, Validation loss : 1.278, Learning rate : 0.003
# epoch : 359, Training loss : 1.140, Validation loss : 0.975, Learning rate : 0.003
# epoch : 360, Training loss : 1.238, Validation loss : 1.443, Learning rate : 0.003
# epoch : 361, Training loss : 1.337, Validation loss : 0.899, Learning rate : 0.003
# epoch : 362, Training loss : 1.279, Validation loss : 1.349, Learning rate : 0.003
# epoch : 363, Training loss : 1.592, Validation loss : 2.589, Learning rate : 0.003
# epoch : 364, Training loss : 1.315, Validation loss : 1.148, Learning rate : 0.003
# epoch : 365, Training loss : 1.325, Validation loss : 0.926, Learning rate : 0.003
# epoch : 366, Training loss : 1.360, Validation loss : 0.917, Learning rate : 0.003
# epoch : 367, Training loss : 1.213, Validation loss : 1.129, Learning rate : 0.003
# epoch : 368, Training loss : 1.408, Validation loss : 0.912, Learning rate : 0.003
# epoch : 369, Training loss : 1.304, Validation loss : 1.255, Learning rate : 0.003
# epoch : 370, Training loss : 1.224, Validation loss : 1.093, Learning rate : 0.003
# epoch : 371, Training loss : 1.407, Validation loss : 1.204, Learning rate : 0.003
# epoch : 372, Training loss : 1.297, Validation loss : 1.164, Learning rate : 0.003
# epoch : 373, Training loss : 1.408, Validation loss : 1.940, Learning rate : 0.003
# epoch : 374, Training loss : 1.442, Validation loss : 1.415, Learning rate : 0.003
# epoch : 375, Training loss : 1.602, Validation loss : 5.703, Learning rate : 0.003
# epoch : 376, Training loss : 1.483, Validation loss : 4.546, Learning rate : 0.003
# epoch : 377, Training loss : 1.794, Validation loss : 1.009, Learning rate : 0.003
# epoch : 378, Training loss : 1.360, Validation loss : 0.854, Learning rate : 0.003
# epoch : 379, Training loss : 1.279, Validation loss : 1.017, Learning rate : 0.003
# epoch : 380, Training loss : 1.403, Validation loss : 1.567, Learning rate : 0.003
# epoch : 381, Training loss : 1.111, Validation loss : 0.817, Learning rate : 0.003
# epoch : 382, Training loss : 1.144, Validation loss : 0.927, Learning rate : 0.003
# epoch : 383, Training loss : 1.465, Validation loss : 3.919, Learning rate : 0.003
# epoch : 384, Training loss : 1.546, Validation loss : 1.207, Learning rate : 0.003
# epoch : 385, Training loss : 1.266, Validation loss : 1.245, Learning rate : 0.003
# epoch : 386, Training loss : 0.935, Validation loss : 0.809, Learning rate : 0.003
# epoch : 387, Training loss : 1.124, Validation loss : 1.019, Learning rate : 0.003
# epoch : 388, Training loss : 1.107, Validation loss : 1.764, Learning rate : 0.003
# epoch : 389, Training loss : 1.227, Validation loss : 2.002, Learning rate : 0.003
# epoch : 390, Training loss : 1.265, Validation loss : 3.159, Learning rate : 0.003
# epoch : 391, Training loss : 1.122, Validation loss : 1.006, Learning rate : 0.003
# epoch : 392, Training loss : 1.224, Validation loss : 2.362, Learning rate : 0.003
# epoch : 393, Training loss : 1.380, Validation loss : 0.813, Learning rate : 0.003
# epoch : 394, Training loss : 0.945, Validation loss : 0.889, Learning rate : 0.003
# epoch : 395, Training loss : 1.473, Validation loss : 2.479, Learning rate : 0.003
# epoch : 396, Training loss : 1.135, Validation loss : 3.151, Learning rate : 0.003
# epoch : 397, Training loss : 0.957, Validation loss : 0.816, Learning rate : 0.003
# epoch : 398, Training loss : 0.994, Validation loss : 0.950, Learning rate : 0.003
# epoch : 399, Training loss : 0.990, Validation loss : 0.708, Learning rate : 0.003
# epoch : 400, Training loss : 1.204, Validation loss : 5.353, Learning rate : 0.003
# epoch : 401, Training loss : 1.256, Validation loss : 2.094, Learning rate : 0.003
# epoch : 402, Training loss : 1.161, Validation loss : 0.733, Learning rate : 0.003
# epoch : 403, Training loss : 1.556, Validation loss : 1.433, Learning rate : 0.003
# epoch : 404, Training loss : 1.380, Validation loss : 1.601, Learning rate : 0.003
# epoch : 405, Training loss : 1.115, Validation loss : 0.895, Learning rate : 0.003
# epoch : 406, Training loss : 1.165, Validation loss : 0.813, Learning rate : 0.003
# epoch : 407, Training loss : 1.091, Validation loss : 1.149, Learning rate : 0.003
# epoch : 408, Training loss : 1.204, Validation loss : 0.864, Learning rate : 0.003
# epoch : 409, Training loss : 1.063, Validation loss : 2.951, Learning rate : 0.003
# epoch : 410, Training loss : 1.107, Validation loss : 1.077, Learning rate : 0.003
# epoch : 411, Training loss : 0.996, Validation loss : 0.756, Learning rate : 0.003
# epoch : 412, Training loss : 1.071, Validation loss : 0.920, Learning rate : 0.003
# epoch : 413, Training loss : 1.008, Validation loss : 0.585, Learning rate : 0.003
# epoch : 414, Training loss : 1.145, Validation loss : 0.924, Learning rate : 0.003
# epoch : 415, Training loss : 1.212, Validation loss : 1.618, Learning rate : 0.003
# epoch : 416, Training loss : 1.182, Validation loss : 5.326, Learning rate : 0.003
# epoch : 417, Training loss : 1.075, Validation loss : 0.660, Learning rate : 0.003
# epoch : 418, Training loss : 1.001, Validation loss : 1.540, Learning rate : 0.003
# epoch : 419, Training loss : 1.008, Validation loss : 1.357, Learning rate : 0.003
# epoch : 420, Training loss : 1.172, Validation loss : 1.369, Learning rate : 0.003
# epoch : 421, Training loss : 0.955, Validation loss : 0.869, Learning rate : 0.003
# epoch : 422, Training loss : 1.343, Validation loss : 0.967, Learning rate : 0.003
# epoch : 423, Training loss : 1.055, Validation loss : 0.737, Learning rate : 0.003
# epoch : 424, Training loss : 1.103, Validation loss : 3.316, Learning rate : 0.003
# epoch : 425, Training loss : 1.129, Validation loss : 3.410, Learning rate : 0.003
# epoch : 426, Training loss : 1.028, Validation loss : 0.820, Learning rate : 0.003
# epoch : 427, Training loss : 0.946, Validation loss : 1.691, Learning rate : 0.003
# epoch : 428, Training loss : 0.937, Validation loss : 1.329, Learning rate : 0.003
# epoch : 429, Training loss : 0.985, Validation loss : 0.882, Learning rate : 0.003
# epoch : 430, Training loss : 1.161, Validation loss : 0.760, Learning rate : 0.003
# epoch : 431, Training loss : 1.226, Validation loss : 1.250, Learning rate : 0.003
# epoch : 432, Training loss : 1.212, Validation loss : 0.812, Learning rate : 0.003
# epoch : 433, Training loss : 1.247, Validation loss : 1.362, Learning rate : 0.003
# epoch : 434, Training loss : 1.086, Validation loss : 1.395, Learning rate : 0.003
# epoch : 435, Training loss : 1.054, Validation loss : 2.850, Learning rate : 0.003
# epoch : 436, Training loss : 1.080, Validation loss : 2.001, Learning rate : 0.003
# epoch : 437, Training loss : 0.917, Validation loss : 1.680, Learning rate : 0.003
# epoch : 438, Training loss : 0.998, Validation loss : 2.758, Learning rate : 0.003
# epoch : 439, Training loss : 1.146, Validation loss : 1.051, Learning rate : 0.003
# epoch : 440, Training loss : 0.904, Validation loss : 0.624, Learning rate : 0.003
# epoch : 441, Training loss : 1.058, Validation loss : 4.373, Learning rate : 0.003
# epoch : 442, Training loss : 1.069, Validation loss : 0.678, Learning rate : 0.003
# epoch : 443, Training loss : 1.103, Validation loss : 4.849, Learning rate : 0.003
# epoch : 444, Training loss : 1.112, Validation loss : 2.158, Learning rate : 0.003
# epoch : 445, Training loss : 1.018, Validation loss : 3.697, Learning rate : 0.003
# epoch : 446, Training loss : 0.856, Validation loss : 0.893, Learning rate : 0.003
# epoch : 447, Training loss : 0.980, Validation loss : 1.068, Learning rate : 0.003
# epoch : 448, Training loss : 0.896, Validation loss : 1.188, Learning rate : 0.003
# epoch : 449, Training loss : 1.162, Validation loss : 1.321, Learning rate : 0.003
# epoch : 450, Training loss : 1.136, Validation loss : 2.295, Learning rate : 0.003
# epoch : 451, Training loss : 1.126, Validation loss : 2.875, Learning rate : 0.003
# epoch : 452, Training loss : 1.171, Validation loss : 0.618, Learning rate : 0.003
# epoch : 453, Training loss : 1.147, Validation loss : 1.147, Learning rate : 0.003
# epoch : 454, Training loss : 1.015, Validation loss : 0.777, Learning rate : 0.003
# epoch : 455, Training loss : 1.107, Validation loss : 0.733, Learning rate : 0.003
# epoch : 456, Training loss : 1.366, Validation loss : 1.713, Learning rate : 0.003
# epoch : 457, Training loss : 0.915, Validation loss : 0.877, Learning rate : 0.003
# epoch : 458, Training loss : 1.057, Validation loss : 1.932, Learning rate : 0.003
# epoch : 459, Training loss : 0.920, Validation loss : 1.067, Learning rate : 0.003
# epoch : 460, Training loss : 1.013, Validation loss : 0.909, Learning rate : 0.003
# epoch : 461, Training loss : 1.065, Validation loss : 1.108, Learning rate : 0.003
# epoch : 462, Training loss : 1.120, Validation loss : 3.415, Learning rate : 0.003
# epoch : 463, Training loss : 1.332, Validation loss : 2.005, Learning rate : 0.003
# epoch : 464, Training loss : 1.007, Validation loss : 1.346, Learning rate : 0.003
# epoch : 465, Training loss : 1.241, Validation loss : 4.259, Learning rate : 0.003
# epoch : 466, Training loss : 1.192, Validation loss : 2.317, Learning rate : 0.003
# epoch : 467, Training loss : 1.182, Validation loss : 1.918, Learning rate : 0.003
# epoch : 468, Training loss : 1.142, Validation loss : 4.929, Learning rate : 0.003
# epoch : 469, Training loss : 1.146, Validation loss : 0.908, Learning rate : 0.003
# epoch : 470, Training loss : 1.046, Validation loss : 0.961, Learning rate : 0.003
# epoch : 471, Training loss : 1.215, Validation loss : 1.463, Learning rate : 0.003
# epoch : 472, Training loss : 1.095, Validation loss : 2.096, Learning rate : 0.003
# epoch : 473, Training loss : 1.030, Validation loss : 1.437, Learning rate : 0.003
# epoch : 474, Training loss : 1.388, Validation loss : 0.635, Learning rate : 0.003
# epoch : 475, Training loss : 1.064, Validation loss : 2.420, Learning rate : 0.003
# epoch : 476, Training loss : 0.959, Validation loss : 0.701, Learning rate : 0.003
# epoch : 477, Training loss : 0.917, Validation loss : 0.808, Learning rate : 0.003
# epoch : 478, Training loss : 0.834, Validation loss : 0.991, Learning rate : 0.003
# epoch : 479, Training loss : 1.067, Validation loss : 1.428, Learning rate : 0.003
# epoch : 480, Training loss : 1.044, Validation loss : 0.655, Learning rate : 0.003
# epoch : 481, Training loss : 1.117, Validation loss : 0.910, Learning rate : 0.003
# epoch : 482, Training loss : 1.057, Validation loss : 0.859, Learning rate : 0.003
# epoch : 483, Training loss : 1.166, Validation loss : 1.193, Learning rate : 0.003
# epoch : 484, Training loss : 1.141, Validation loss : 0.691, Learning rate : 0.003
# epoch : 485, Training loss : 1.056, Validation loss : 2.727, Learning rate : 0.003
# epoch : 486, Training loss : 1.129, Validation loss : 1.273, Learning rate : 0.003
# epoch : 487, Training loss : 0.827, Validation loss : 3.335, Learning rate : 0.003
# epoch : 488, Training loss : 0.893, Validation loss : 0.877, Learning rate : 0.003
# epoch : 489, Training loss : 0.893, Validation loss : 1.010, Learning rate : 0.003
# epoch : 490, Training loss : 0.881, Validation loss : 0.999, Learning rate : 0.003
# epoch : 491, Training loss : 1.017, Validation loss : 0.857, Learning rate : 0.003
# epoch : 492, Training loss : 0.894, Validation loss : 2.517, Learning rate : 0.003
# epoch : 493, Training loss : 1.057, Validation loss : 1.192, Learning rate : 0.003
# epoch : 494, Training loss : 1.134, Validation loss : 2.966, Learning rate : 0.003
# epoch : 495, Training loss : 1.019, Validation loss : 0.908, Learning rate : 0.003
# epoch : 496, Training loss : 1.151, Validation loss : 4.484, Learning rate : 0.003
# epoch : 497, Training loss : 1.005, Validation loss : 3.883, Learning rate : 0.003
# epoch : 498, Training loss : 1.045, Validation loss : 1.437, Learning rate : 0.003
# epoch : 499, Training loss : 0.975, Validation loss : 0.952, Learning rate : 0.003
# epoch : 500, Training loss : 1.063, Validation loss : 2.684, Learning rate : 0.003
# epoch : 501, Training loss : 0.945, Validation loss : 0.758, Learning rate : 0.003
# epoch : 502, Training loss : 0.878, Validation loss : 0.983, Learning rate : 0.003
# epoch : 503, Training loss : 1.046, Validation loss : 1.840, Learning rate : 0.003
# epoch : 504, Training loss : 0.989, Validation loss : 0.775, Learning rate : 0.003
# epoch : 505, Training loss : 1.105, Validation loss : 1.125, Learning rate : 0.003
# epoch : 506, Training loss : 0.960, Validation loss : 0.776, Learning rate : 0.003
# epoch : 507, Training loss : 0.963, Validation loss : 0.987, Learning rate : 0.003
# epoch : 508, Training loss : 0.879, Validation loss : 1.040, Learning rate : 0.003
# epoch : 509, Training loss : 0.972, Validation loss : 0.750, Learning rate : 0.003
# epoch : 510, Training loss : 1.016, Validation loss : 2.746, Learning rate : 0.003
# epoch : 511, Training loss : 0.847, Validation loss : 0.992, Learning rate : 0.003
# epoch : 512, Training loss : 1.015, Validation loss : 0.643, Learning rate : 0.003
# epoch : 513, Training loss : 0.861, Validation loss : 0.848, Learning rate : 0.003
# epoch : 514, Training loss : 0.893, Validation loss : 0.647, Learning rate : 0.003
# epoch : 515, Training loss : 0.964, Validation loss : 0.668, Learning rate : 0.003
# epoch : 516, Training loss : 0.942, Validation loss : 1.029, Learning rate : 0.003
# epoch : 517, Training loss : 0.910, Validation loss : 1.226, Learning rate : 0.003
# epoch : 518, Training loss : 0.894, Validation loss : 0.809, Learning rate : 0.003
# epoch : 519, Training loss : 0.774, Validation loss : 0.711, Learning rate : 0.003
# epoch : 520, Training loss : 1.029, Validation loss : 3.766, Learning rate : 0.003
# epoch : 521, Training loss : 1.044, Validation loss : 2.236, Learning rate : 0.003
# epoch : 522, Training loss : 1.211, Validation loss : 0.728, Learning rate : 0.003
# epoch : 523, Training loss : 0.944, Validation loss : 1.127, Learning rate : 0.003
# epoch : 524, Training loss : 0.909, Validation loss : 1.772, Learning rate : 0.003
# epoch : 525, Training loss : 0.937, Validation loss : 0.681, Learning rate : 0.003
# epoch : 526, Training loss : 0.991, Validation loss : 0.596, Learning rate : 0.003
# epoch : 527, Training loss : 0.965, Validation loss : 0.933, Learning rate : 0.003
# epoch : 528, Training loss : 0.914, Validation loss : 0.879, Learning rate : 0.003
# epoch : 529, Training loss : 1.073, Validation loss : 3.652, Learning rate : 0.003
# epoch : 530, Training loss : 0.929, Validation loss : 0.759, Learning rate : 0.003
# epoch : 531, Training loss : 0.819, Validation loss : 0.765, Learning rate : 0.003
# epoch : 532, Training loss : 0.867, Validation loss : 0.778, Learning rate : 0.003
# epoch : 533, Training loss : 1.099, Validation loss : 0.657, Learning rate : 0.003
# epoch : 534, Training loss : 0.805, Validation loss : 1.030, Learning rate : 0.003
# epoch : 535, Training loss : 0.812, Validation loss : 0.768, Learning rate : 0.003
# epoch : 536, Training loss : 1.006, Validation loss : 0.637, Learning rate : 0.003
# epoch : 537, Training loss : 1.023, Validation loss : 1.097, Learning rate : 0.003
# epoch : 538, Training loss : 0.887, Validation loss : 1.049, Learning rate : 0.003
# epoch : 539, Training loss : 0.922, Validation loss : 1.635, Learning rate : 0.003
# epoch : 540, Training loss : 0.957, Validation loss : 1.072, Learning rate : 0.003
# epoch : 541, Training loss : 0.900, Validation loss : 0.554, Learning rate : 0.003
# epoch : 542, Training loss : 0.866, Validation loss : 0.681, Learning rate : 0.003
# epoch : 543, Training loss : 1.037, Validation loss : 0.599, Learning rate : 0.003
# epoch : 544, Training loss : 0.952, Validation loss : 2.783, Learning rate : 0.003
# epoch : 545, Training loss : 1.166, Validation loss : 3.024, Learning rate : 0.003
# epoch : 546, Training loss : 0.906, Validation loss : 0.768, Learning rate : 0.003
# epoch : 547, Training loss : 0.736, Validation loss : 0.567, Learning rate : 0.003
# epoch : 548, Training loss : 0.853, Validation loss : 1.020, Learning rate : 0.003
# epoch : 549, Training loss : 0.934, Validation loss : 0.691, Learning rate : 0.003
# epoch : 550, Training loss : 0.849, Validation loss : 0.715, Learning rate : 0.003
# epoch : 551, Training loss : 0.784, Validation loss : 1.241, Learning rate : 0.003
# epoch : 552, Training loss : 0.844, Validation loss : 0.647, Learning rate : 0.003
# epoch : 553, Training loss : 0.896, Validation loss : 0.662, Learning rate : 0.003
# epoch : 554, Training loss : 0.761, Validation loss : 0.752, Learning rate : 0.003
# epoch : 555, Training loss : 0.736, Validation loss : 0.776, Learning rate : 0.003
# epoch : 556, Training loss : 0.959, Validation loss : 3.235, Learning rate : 0.003
# epoch : 557, Training loss : 1.002, Validation loss : 0.789, Learning rate : 0.003
# epoch : 558, Training loss : 0.827, Validation loss : 2.791, Learning rate : 0.003
# epoch : 559, Training loss : 0.909, Validation loss : 0.840, Learning rate : 0.003
# epoch : 560, Training loss : 0.767, Validation loss : 0.885, Learning rate : 0.003
# epoch : 561, Training loss : 1.038, Validation loss : 1.829, Learning rate : 0.003
# epoch : 562, Training loss : 0.770, Validation loss : 0.620, Learning rate : 0.003
# epoch : 563, Training loss : 0.832, Validation loss : 1.144, Learning rate : 0.003
# epoch : 564, Training loss : 0.746, Validation loss : 0.545, Learning rate : 0.003
# epoch : 565, Training loss : 0.788, Validation loss : 0.925, Learning rate : 0.003
# epoch : 566, Training loss : 0.895, Validation loss : 0.628, Learning rate : 0.003
# epoch : 567, Training loss : 0.703, Validation loss : 0.814, Learning rate : 0.003
# epoch : 568, Training loss : 1.019, Validation loss : 0.595, Learning rate : 0.003
# epoch : 569, Training loss : 0.916, Validation loss : 1.359, Learning rate : 0.003
# epoch : 570, Training loss : 0.840, Validation loss : 0.688, Learning rate : 0.003
# epoch : 571, Training loss : 0.884, Validation loss : 0.868, Learning rate : 0.003
# epoch : 572, Training loss : 1.007, Validation loss : 2.058, Learning rate : 0.003
# epoch : 573, Training loss : 0.843, Validation loss : 0.842, Learning rate : 0.003
# epoch : 574, Training loss : 0.760, Validation loss : 0.548, Learning rate : 0.003
# epoch : 575, Training loss : 0.809, Validation loss : 0.605, Learning rate : 0.003
# epoch : 576, Training loss : 0.838, Validation loss : 0.717, Learning rate : 0.003
# ...
# epoch : 3811, Training loss : 0.287, Validation loss : 0.253, Learning rate : 0.001
# epoch : 3812, Training loss : 0.286, Validation loss : 0.285, Learning rate : 0.001
# epoch : 3813, Training loss : 0.332, Validation loss : 0.231, Learning rate : 0.001
# epoch : 3814, Training loss : 0.280, Validation loss : 0.247, Learning rate : 0.001
# epoch : 3815, Training loss : 0.332, Validation loss : 0.357, Learning rate : 0.001
# epoch : 3816, Training loss : 0.279, Validation loss : 0.263, Learning rate : 0.001
# epoch : 3817, Training loss : 0.306, Validation loss : 0.213, Learning rate : 0.001
# epoch : 3818, Training loss : 0.309, Validation loss : 0.424, Learning rate : 0.001
# epoch : 3819, Training loss : 0.325, Validation loss : 0.296, Learning rate : 0.001
# epoch : 3820, Training loss : 0.307, Validation loss : 0.272, Learning rate : 0.001
# epoch : 3821, Training loss : 0.303, Validation loss : 0.259, Learning rate : 0.001
# epoch : 3822, Training loss : 0.333, Validation loss : 0.257, Learning rate : 0.001
# epoch : 3823, Training loss : 0.311, Validation loss : 0.275, Learning rate : 0.001
# epoch : 3824, Training loss : 0.360, Validation loss : 0.255, Learning rate : 0.001
# epoch : 3825, Training loss : 0.308, Validation loss : 0.313, Learning rate : 0.001
# epoch : 3826, Training loss : 0.305, Validation loss : 0.296, Learning rate : 0.001
# epoch : 3827, Training loss : 0.323, Validation loss : 0.257, Learning rate : 0.001
# epoch : 3828, Training loss : 0.257, Validation loss : 0.280, Learning rate : 0.001
# epoch : 3829, Training loss : 0.298, Validation loss : 0.391, Learning rate : 0.001
# epoch : 3830, Training loss : 0.305, Validation loss : 0.429, Learning rate : 0.001
# epoch : 3831, Training loss : 0.359, Validation loss : 0.333, Learning rate : 0.001
# epoch : 3832, Training loss : 0.311, Validation loss : 0.292, Learning rate : 0.001
# epoch : 3833, Training loss : 0.309, Validation loss : 0.248, Learning rate : 0.001
# epoch : 3834, Training loss : 0.319, Validation loss : 0.290, Learning rate : 0.001
# epoch : 3835, Training loss : 0.288, Validation loss : 0.278, Learning rate : 0.001
# epoch : 3836, Training loss : 0.324, Validation loss : 0.183, Learning rate : 0.001
# epoch : 3837, Training loss : 0.313, Validation loss : 0.433, Learning rate : 0.001
# epoch : 3838, Training loss : 0.338, Validation loss : 0.356, Learning rate : 0.001
# epoch : 3839, Training loss : 0.320, Validation loss : 0.291, Learning rate : 0.001
# epoch : 3840, Training loss : 0.282, Validation loss : 0.358, Learning rate : 0.001
# epoch : 3841, Training loss : 0.312, Validation loss : 0.212, Learning rate : 0.001
# epoch : 3842, Training loss : 0.325, Validation loss : 0.216, Learning rate : 0.001
# epoch : 3843, Training loss : 0.328, Validation loss : 0.236, Learning rate : 0.001
# epoch : 3844, Training loss : 0.328, Validation loss : 0.276, Learning rate : 0.001
# epoch : 3845, Training loss : 0.316, Validation loss : 0.218, Learning rate : 0.001
# epoch : 3846, Training loss : 0.307, Validation loss : 0.295, Learning rate : 0.001
# epoch : 3847, Training loss : 0.335, Validation loss : 0.220, Learning rate : 0.001
# epoch : 3848, Training loss : 0.289, Validation loss : 0.191, Learning rate : 0.001
# epoch : 3849, Training loss : 0.337, Validation loss : 0.220, Learning rate : 0.001
# epoch : 3850, Training loss : 0.323, Validation loss : 0.179, Learning rate : 0.001
# epoch : 3851, Training loss : 0.298, Validation loss : 0.237, Learning rate : 0.001
# epoch : 3852, Training loss : 0.307, Validation loss : 0.232, Learning rate : 0.001
# epoch : 3853, Training loss : 0.336, Validation loss : 0.209, Learning rate : 0.001
# epoch : 3854, Training loss : 0.318, Validation loss : 0.310, Learning rate : 0.001
# epoch : 3855, Training loss : 0.294, Validation loss : 0.353, Learning rate : 0.001
# epoch : 3856, Training loss : 0.341, Validation loss : 0.596, Learning rate : 0.001
# epoch : 3857, Training loss : 0.355, Validation loss : 0.225, Learning rate : 0.001
# epoch : 3858, Training loss : 0.298, Validation loss : 0.238, Learning rate : 0.001
# epoch : 3859, Training loss : 0.313, Validation loss : 0.316, Learning rate : 0.001
# epoch : 3860, Training loss : 0.315, Validation loss : 0.260, Learning rate : 0.001
# epoch : 3861, Training loss : 0.283, Validation loss : 0.583, Learning rate : 0.001
# epoch : 3862, Training loss : 0.338, Validation loss : 0.214, Learning rate : 0.001
# epoch : 3863, Training loss : 0.311, Validation loss : 0.286, Learning rate : 0.001
# epoch : 3864, Training loss : 0.311, Validation loss : 0.184, Learning rate : 0.001
# epoch : 3865, Training loss : 0.312, Validation loss : 0.297, Learning rate : 0.001
# epoch : 3866, Training loss : 0.355, Validation loss : 0.520, Learning rate : 0.001
# epoch : 3867, Training loss : 0.305, Validation loss : 0.216, Learning rate : 0.001
# epoch : 3868, Training loss : 0.298, Validation loss : 0.197, Learning rate : 0.001
# epoch : 3869, Training loss : 0.290, Validation loss : 0.278, Learning rate : 0.001
# epoch : 3870, Training loss : 0.297, Validation loss : 0.259, Learning rate : 0.001
# epoch : 3871, Training loss : 0.305, Validation loss : 0.235, Learning rate : 0.001
# epoch : 3872, Training loss : 0.308, Validation loss : 0.162, Learning rate : 0.001
# epoch : 3873, Training loss : 0.307, Validation loss : 0.217, Learning rate : 0.001
# epoch : 3874, Training loss : 0.277, Validation loss : 0.337, Learning rate : 0.001
# epoch : 3875, Training loss : 0.326, Validation loss : 0.283, Learning rate : 0.001
# epoch : 3876, Training loss : 0.337, Validation loss : 0.255, Learning rate : 0.001
# epoch : 3877, Training loss : 0.325, Validation loss : 0.332, Learning rate : 0.001
# epoch : 3878, Training loss : 0.342, Validation loss : 0.210, Learning rate : 0.001
# epoch : 3879, Training loss : 0.319, Validation loss : 0.561, Learning rate : 0.001
# epoch : 3880, Training loss : 0.333, Validation loss : 0.209, Learning rate : 0.001
# epoch : 3881, Training loss : 0.304, Validation loss : 0.209, Learning rate : 0.001
# epoch : 3882, Training loss : 0.309, Validation loss : 0.298, Learning rate : 0.001
# epoch : 3883, Training loss : 0.292, Validation loss : 0.248, Learning rate : 0.001
# epoch : 3884, Training loss : 0.310, Validation loss : 0.308, Learning rate : 0.001
# epoch : 3885, Training loss : 0.325, Validation loss : 0.395, Learning rate : 0.001
# epoch : 3886, Training loss : 0.326, Validation loss : 0.235, Learning rate : 0.001
# epoch : 3887, Training loss : 0.317, Validation loss : 0.309, Learning rate : 0.001
# epoch : 3888, Training loss : 0.298, Validation loss : 0.243, Learning rate : 0.001
# epoch : 3889, Training loss : 0.328, Validation loss : 0.261, Learning rate : 0.001
# epoch : 3890, Training loss : 0.287, Validation loss : 0.255, Learning rate : 0.001
# epoch : 3891, Training loss : 0.332, Validation loss : 0.266, Learning rate : 0.001
# epoch : 3892, Training loss : 0.292, Validation loss : 0.331, Learning rate : 0.001
# epoch : 3893, Training loss : 0.341, Validation loss : 0.275, Learning rate : 0.001
# epoch : 3894, Training loss : 0.275, Validation loss : 0.253, Learning rate : 0.001
# epoch : 3895, Training loss : 0.292, Validation loss : 0.417, Learning rate : 0.001
# epoch : 3896, Training loss : 0.324, Validation loss : 0.587, Learning rate : 0.001
# epoch : 3897, Training loss : 0.292, Validation loss : 0.235, Learning rate : 0.001
# epoch : 3898, Training loss : 0.316, Validation loss : 0.219, Learning rate : 0.001
# epoch : 3899, Training loss : 0.318, Validation loss : 0.314, Learning rate : 0.001
# epoch : 3900, Training loss : 0.345, Validation loss : 0.233, Learning rate : 0.001
# epoch : 3901, Training loss : 0.290, Validation loss : 0.293, Learning rate : 0.001
# epoch : 3902, Training loss : 0.350, Validation loss : 0.312, Learning rate : 0.001
# epoch : 3903, Training loss : 0.313, Validation loss : 0.202, Learning rate : 0.001
# epoch : 3904, Training loss : 0.329, Validation loss : 0.316, Learning rate : 0.001
# epoch : 3905, Training loss : 0.287, Validation loss : 0.205, Learning rate : 0.001
# epoch : 3906, Training loss : 0.376, Validation loss : 0.480, Learning rate : 0.001
# epoch : 3907, Training loss : 0.350, Validation loss : 0.245, Learning rate : 0.001
# epoch : 3908, Training loss : 0.276, Validation loss : 0.264, Learning rate : 0.001
# epoch : 3909, Training loss : 0.324, Validation loss : 0.209, Learning rate : 0.001
# epoch : 3910, Training loss : 0.314, Validation loss : 0.268, Learning rate : 0.001
# epoch : 3911, Training loss : 0.298, Validation loss : 0.238, Learning rate : 0.001
# epoch : 3912, Training loss : 0.313, Validation loss : 0.250, Learning rate : 0.001
# epoch : 3913, Training loss : 0.379, Validation loss : 0.654, Learning rate : 0.001
# epoch : 3914, Training loss : 0.330, Validation loss : 0.258, Learning rate : 0.001
# epoch : 3915, Training loss : 0.328, Validation loss : 0.228, Learning rate : 0.001
# epoch : 3916, Training loss : 0.320, Validation loss : 0.306, Learning rate : 0.001
# epoch : 3917, Training loss : 0.347, Validation loss : 0.254, Learning rate : 0.001
# epoch : 3918, Training loss : 0.299, Validation loss : 0.312, Learning rate : 0.001
# epoch : 3919, Training loss : 0.327, Validation loss : 0.224, Learning rate : 0.001
# epoch : 3920, Training loss : 0.290, Validation loss : 0.381, Learning rate : 0.001
# epoch : 3921, Training loss : 0.325, Validation loss : 0.274, Learning rate : 0.001
# epoch : 3922, Training loss : 0.294, Validation loss : 0.274, Learning rate : 0.001
# epoch : 3923, Training loss : 0.326, Validation loss : 0.279, Learning rate : 0.001
# epoch : 3924, Training loss : 0.313, Validation loss : 0.498, Learning rate : 0.001
# epoch : 3925, Training loss : 0.332, Validation loss : 0.245, Learning rate : 0.001
# epoch : 3926, Training loss : 0.305, Validation loss : 0.609, Learning rate : 0.001
# epoch : 3927, Training loss : 0.360, Validation loss : 0.259, Learning rate : 0.001
# epoch : 3928, Training loss : 0.336, Validation loss : 0.234, Learning rate : 0.001
# epoch : 3929, Training loss : 0.304, Validation loss : 0.384, Learning rate : 0.001
# epoch : 3930, Training loss : 0.301, Validation loss : 0.251, Learning rate : 0.001
# epoch : 3931, Training loss : 0.349, Validation loss : 0.383, Learning rate : 0.001
# epoch : 3932, Training loss : 0.336, Validation loss : 0.333, Learning rate : 0.001
# epoch : 3933, Training loss : 0.325, Validation loss : 0.218, Learning rate : 0.001
# epoch : 3934, Training loss : 0.396, Validation loss : 0.305, Learning rate : 0.001
# epoch : 3935, Training loss : 0.309, Validation loss : 0.251, Learning rate : 0.001
# epoch : 3936, Training loss : 0.250, Validation loss : 0.216, Learning rate : 0.001
# epoch : 3937, Training loss : 0.324, Validation loss : 0.334, Learning rate : 0.001
# epoch : 3938, Training loss : 0.289, Validation loss : 0.423, Learning rate : 0.001
# epoch : 3939, Training loss : 0.344, Validation loss : 0.225, Learning rate : 0.001
# epoch : 3940, Training loss : 0.277, Validation loss : 0.236, Learning rate : 0.001
# epoch : 3941, Training loss : 0.320, Validation loss : 0.527, Learning rate : 0.001
# epoch : 3942, Training loss : 0.347, Validation loss : 0.401, Learning rate : 0.001
# epoch : 3943, Training loss : 0.338, Validation loss : 0.235, Learning rate : 0.001
# epoch : 3944, Training loss : 0.281, Validation loss : 0.271, Learning rate : 0.001
# epoch : 3945, Training loss : 0.316, Validation loss : 0.284, Learning rate : 0.001
# epoch : 3946, Training loss : 0.316, Validation loss : 0.342, Learning rate : 0.001
# epoch : 3947, Training loss : 0.341, Validation loss : 0.242, Learning rate : 0.001
# epoch : 3948, Training loss : 0.330, Validation loss : 0.362, Learning rate : 0.001
# epoch : 3949, Training loss : 0.328, Validation loss : 0.254, Learning rate : 0.001
# epoch : 3950, Training loss : 0.336, Validation loss : 0.243, Learning rate : 0.001
# epoch : 3951, Training loss : 0.318, Validation loss : 0.246, Learning rate : 0.001
# epoch : 3952, Training loss : 0.340, Validation loss : 0.398, Learning rate : 0.001
# epoch : 3953, Training loss : 0.352, Validation loss : 0.255, Learning rate : 0.001
# epoch : 3954, Training loss : 0.309, Validation loss : 0.273, Learning rate : 0.001
# epoch : 3955, Training loss : 0.303, Validation loss : 0.416, Learning rate : 0.001
# epoch : 3956, Training loss : 0.311, Validation loss : 0.238, Learning rate : 0.001
# epoch : 3957, Training loss : 0.287, Validation loss : 0.305, Learning rate : 0.001
# epoch : 3958, Training loss : 0.315, Validation loss : 0.237, Learning rate : 0.001
# epoch : 3959, Training loss : 0.311, Validation loss : 0.209, Learning rate : 0.001
# epoch : 3960, Training loss : 0.317, Validation loss : 0.282, Learning rate : 0.001
# epoch : 3961, Training loss : 0.335, Validation loss : 0.252, Learning rate : 0.001
# epoch : 3962, Training loss : 0.318, Validation loss : 0.310, Learning rate : 0.001
# epoch : 3963, Training loss : 0.382, Validation loss : 0.281, Learning rate : 0.001
# epoch : 3964, Training loss : 0.342, Validation loss : 0.481, Learning rate : 0.001
# epoch : 3965, Training loss : 0.311, Validation loss : 0.236, Learning rate : 0.001
# epoch : 3966, Training loss : 0.332, Validation loss : 0.253, Learning rate : 0.001
# epoch : 3967, Training loss : 0.281, Validation loss : 0.282, Learning rate : 0.001
# epoch : 3968, Training loss : 0.300, Validation loss : 0.251, Learning rate : 0.001
# epoch : 3969, Training loss : 0.307, Validation loss : 0.284, Learning rate : 0.001
# epoch : 3970, Training loss : 0.306, Validation loss : 0.279, Learning rate : 0.001
# epoch : 3971, Training loss : 0.334, Validation loss : 0.449, Learning rate : 0.001
# epoch : 3972, Training loss : 0.314, Validation loss : 0.307, Learning rate : 0.001
# epoch : 3973, Training loss : 0.315, Validation loss : 0.204, Learning rate : 0.001
# epoch : 3974, Training loss : 0.296, Validation loss : 0.468, Learning rate : 0.001
# epoch : 3975, Training loss : 0.296, Validation loss : 0.258, Learning rate : 0.001
# epoch : 3976, Training loss : 0.322, Validation loss : 0.228, Learning rate : 0.001
# epoch : 3977, Training loss : 0.289, Validation loss : 0.209, Learning rate : 0.001
# epoch : 3978, Training loss : 0.316, Validation loss : 0.263, Learning rate : 0.001
# epoch : 3979, Training loss : 0.274, Validation loss : 0.213, Learning rate : 0.001
# epoch : 3980, Training loss : 0.312, Validation loss : 0.304, Learning rate : 0.001
# epoch : 3981, Training loss : 0.304, Validation loss : 0.291, Learning rate : 0.001
# epoch : 3982, Training loss : 0.308, Validation loss : 0.247, Learning rate : 0.001
# epoch : 3983, Training loss : 0.346, Validation loss : 0.285, Learning rate : 0.001
# epoch : 3984, Training loss : 0.317, Validation loss : 0.224, Learning rate : 0.001
# epoch : 3985, Training loss : 0.298, Validation loss : 0.329, Learning rate : 0.001
# epoch : 3986, Training loss : 0.332, Validation loss : 0.387, Learning rate : 0.001
# epoch : 3987, Training loss : 0.309, Validation loss : 0.591, Learning rate : 0.001
# epoch : 3988, Training loss : 0.357, Validation loss : 0.303, Learning rate : 0.001
# epoch : 3989, Training loss : 0.297, Validation loss : 0.391, Learning rate : 0.001
# epoch : 3990, Training loss : 0.299, Validation loss : 0.336, Learning rate : 0.001
# epoch : 3991, Training loss : 0.310, Validation loss : 0.275, Learning rate : 0.001
# epoch : 3992, Training loss : 0.320, Validation loss : 0.234, Learning rate : 0.001
# epoch : 3993, Training loss : 0.316, Validation loss : 0.303, Learning rate : 0.001
# epoch : 3994, Training loss : 0.306, Validation loss : 0.223, Learning rate : 0.001
# epoch : 3995, Training loss : 0.305, Validation loss : 0.228, Learning rate : 0.001
# epoch : 3996, Training loss : 0.289, Validation loss : 0.305, Learning rate : 0.001
# epoch : 3997, Training loss : 0.310, Validation loss : 0.478, Learning rate : 0.001
# epoch : 3998, Training loss : 0.316, Validation loss : 0.299, Learning rate : 0.001
# epoch : 3999, Training loss : 0.271, Validation loss : 0.298, Learning rate : 0.001
# epoch : 4000, Training loss : 0.332, Validation loss : 0.326, Learning rate : 0.001

# %%
plt.plot(validation_loss[100:], color='red', label='Validation Loss')
plt.plot(training_loss[100:], color='blue', label='Training Loss')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(learning_rate)
plt.show()

# %%
FILE = "model2.pth"
torch.save(model.state_dict(), FILE)

# %% [markdown]
# # Model Testing

# %%
dataclass
class ModelArgsTest:
    dim: int = 256
    n_layers: int = 2
    n_heads: int = 8
    n_kv_heads: Optional[int] = None
    #vocab_size: int = 32000
    n_features : int = len(req_parameters)
    hidden_dim: Optional[int] = None
    multiple_of: int = 256  # MLP hidden layer size will be multiple of
    norm_eps: float = 1e-5
    max_seq_len: int = 300
    dropout: float = 0.2

    max_batch_size : int = 1

params = ModelArgsTest

# %%
def generate_final_test_dataset(path_location):

    input_batches = []
    output_batches = []

    all_files = os.listdir(path_location)
    file_paths = [os.path.join(path_location, file) for file in all_files]

    for file in file_paths :
        df = pd.read_csv(file, delimiter=';', encoding='ISO-8859-1')
        df = df[req_parameters]
        df['SoC [%]'] = df['SoC [%]'].shift(1)
        df = df.rename(columns={'SoC [%]' : 'prevsoc'})
        df.dropna(inplace=True)

        input_tensors = []
        output_tensors = []
        start_index = 0
        for index, row in df.iterrows():
            if index == (len(df) - 1):
                break
            if (index + 1) % params.max_seq_len == 0:
                input_tensor = torch.tensor(df.iloc[start_index : index + 1].values, dtype=torch.float32).to(device)
                output_tensor = torch.tensor(df.iloc[index+1, df.columns.get_loc('prevsoc')], dtype=torch.float32).to(device)

                input_tensors.append(input_tensor)
                output_tensors.append(output_tensor)

                start_index = index + 1

        temp_input_batches = []
        temp_output_batches = []

        for i in range(0, len(input_tensors), params.max_batch_size):
            input_batch =  torch.stack(input_tensors[i:i+params.max_batch_size])
            temp_input_batches.append(input_batch)

            output_batch =  torch.stack(output_tensors[i:i+params.max_batch_size])
            temp_output_batches.append(output_batch)

        temp_input_batches = temp_input_batches[:-1]
        temp_output_batches = temp_output_batches[:-1]

        input_batches += temp_input_batches
        output_batches += temp_output_batches

    return input_batches, output_batches

path_location = 'summer_dataset'
input_batches, output_batches = generate_final_test_dataset(path_location)

print(f'Size of dataset : {len(input_batches)}')
# Out:
# Size of dataset : 1511

# %%
FILE = "model2.pth"

model = Transformer(ModelArgsTest)
model.load_state_dict(torch.load(FILE))
model.to(device)
# Out:
# Transformer(
#   (tok_embeddings): Linear(in_features=7, out_features=256, bias=False)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (layers): ModuleList(
#     (0-1): 2 x TransformerBlock(
#       (attention): Attention(
#         (wq): Linear(in_features=256, out_features=256, bias=False)
#         (wk): Linear(in_features=256, out_features=256, bias=False)
#         (wv): Linear(in_features=256, out_features=256, bias=False)
#         (wo): Linear(in_features=256, out_features=256, bias=False)
#         (attn_dropout): Dropout(p=0.2, inplace=False)
#         (resid_dropout): Dropout(p=0.2, inplace=False)
#       )
#       (feed_forward): FeedForward(
#         (w1): Linear(in_features=256, out_features=768, bias=False)
#         (w2): Linear(in_features=768, out_features=256, bias=False)
#         (w3): Linear(in_features=256, out_features=768, bias=False)
#         (dropout): Dropout(p=0.2, inplace=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#   )
#   (norm): RMSNorm()
#   (output): Linear(in_features=256, out_features=1, bias=False)
# )

# %%
criterion = nn.MSELoss()

output = []
original_output = []

total_loss = 0
count = 0

with torch.no_grad():
    for i in range(len(input_batches)):

        calc_output = model(input_batches[i])
        output.append(calc_output.item())

        correct_output = output_batches[i]
        original_output.append(correct_output.item())
        
        loss = criterion(calc_output, correct_output)
        total_loss += loss.item()
        count += 1

print(f'Total MSE loss : {total_loss / count}')
# Out:
# Total MSE loss : 0.34754241094171395

# %%
plt.plot(output)
plt.plot(original_output)

plt.show()

# %%
'''
Things to do :
(1) Saving the best model
(2) Early stopping
(3) Transfer learning on winter dataset
'''
